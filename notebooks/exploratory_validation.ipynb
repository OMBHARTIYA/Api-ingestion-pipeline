# %% [markdown]
# # Exploratory Validation
#
# This notebook is a lightweight placeholder for validating synthetic outputs from the API ingestion pipeline.
#
# Suggested checks:
# - Review row counts across raw, bronze, silver, and gold layers.
# - Inspect status distributions and latest-event flags.
# - Sample project and contractor summaries for plausibility.
